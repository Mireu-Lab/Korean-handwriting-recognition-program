# %%
import cv2, sys
from matplotlib import pyplot as plt
import numpy as np

# %%
image = cv2.imread('dataset_dir/13.한국어글자체/01.손글씨/01_handwriting_sentence_images/1_sentence/00000002.png', cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(image)
plt.xticks([])
plt.yticks([])
plt.show()

# %%
blur = cv2.GaussianBlur(image_gray, ksize=(3,3), sigmaX=0)
ret, thresh1 = cv2.threshold(blur, 127, 255, cv2.THRESH_BINARY)

# %%
plt.imshow(blur)
plt.xticks([])
plt.yticks([])
plt.show()

# %%
import cv2

# 이미지 파일 로드
image = cv2.imread('dataset_dir/13.한국어글자체/01.손글씨/01_handwriting_sentence_images/1_sentence/00000002.png')

# 추출할 영역 좌표 설정
x = 0
y = 0
width = 300
height = 200

# 이미지에서 영역 추출
cropped_image = image[y:y+height, x:x+width]

# 추출된 영역 이미지 저장
cv2.imwrite('dataset_dir/13.한국어글자체/01.손글씨/01_handwriting_sentence_images/00000002.png', cropped_image)
# Out:
# True
