# %%
from PIL import Image, ImageDraw, ImageOps
import numpy as np
import cv2

# %%
img = Image.open("../dataset_dir/13.한국어글자체/01.손글씨/01_handwriting_sentence_images/1_sentence/00000002.png")
img.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=3755x176>

# %%
grayscale_image = ImageOps.grayscale(im).convert('L')
grayscale_image.show()
# Out:
# <PIL.Image.Image image mode=L size=3755x176>
