# %%
from json import *

# %%
jsondata = load(open("../dataset_dir/13.한국어글자체/01.손글씨/handwriting_data_info_clean.json", "r"))

# %%
jsondata["annotations"]
# Out:
# [{'id': '00000002',
#   'image_id': '00000002',
#   'text': '이 죽어갔다"며 "문 후보는 당시 민정수석으로 공권력 집행의 최종 결',
#   'attributes': {'type': '문장', 'gender': '여', 'age': '28', 'job': '직장인'}},
#  {'id': '00000003',
#   'image_id': '00000003',
#   'text': '정권자였는데 이에 대한 사과가 우선"이라고 했다. 한편 문 후보와 김',
#   'attributes': {'type': '문장', 'gender': '여', 'age': '28', 'job': '직장인'}},
#  {'id': '00000004',
#   'image_id': '00000004',
#   'text': '위원장과의 악연도 화제였다. 두 사람의 악연은 지난 2003년 철도노',
#   'attributes': {'type': '문장', 'gender': '여', 'age': '28', 'job': '직장인'}},
#  {'id': '00000005',
#   'image_id': '00000005',
#   'text': '조 파업 때로 거슬러 올라 간다. 문 후보는 당시 청와대 민정수석으로',
#   'attributes': {'type': '문장', 'gender': '여', 'age': '28', 'job': '직장인'}},
#  {'id': '00000006',
#   'image_id': '00000006',
#   'text': '노조 파업에 공권력 투입을 사실상 결정했고, 김 위원장은 철도노조',
#   'attributes': {'type': '문장', 'gender': '여', 'age': '28', 'job': '직장인'}},
#  {'id': '00000007',
#   'image_id': '00000007',
# ...

# %%
import pandas as pd

df = pd.DataFrame.from_records(jsondata["annotations"])
df = df.drop("attributes", axis=1)

# %%
import sqlite3

con = sqlite3.connect("../dataset.sqlite")
df.to_sql("handwriting_dataset", con, index=0)
# Out:
# 1142045
