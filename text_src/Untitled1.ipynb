# %%
import os

dirList = os.listdir("../dataset_dir/13.한국어글자체/image")

age = 0
    
for dir in dirList:
    file = os.listdir(f"../dataset_dir/13.한국어글자체/image/{dir}")
    age += len(file)
    
    print(dir, len(file))
# Out:
# 뵿 65
# 흩 61
# 튁 54
# 벴 63
# 쫋 64
# 낫 67
# 쫬 62
# 돀 66
# 긫 66
# 숴 68
# 첽 68
# 쉝 67
# 놌 61
# 먃 68
# 즩 66
# 괤 67
# 헱 62
# 뎜 62
# 촲 69
# 듰 17
# 빎 64
# 뤨 67
# 뚔 67
# 뭖 67
# 캻 65
# 꽦 67
# 홦 68
# 톛 65
# 택 66
# 눭 68
# 첤 68
# 끞 67
# 돍 68
# 묷 67
# 럯 66
# 묳 66
# 쵅 69
# 쳭 68
# 뽻 67
# 꽅 68
# 껯 68
# 댧 68
# 츢 64
# 떦 67
# 옴 67
# 른 68
# 셆 65
# 버 57
# 삦 65
# 썊 66
# 줗 66
# 왺 69
# 븼 67
# 픯 66
# 떩 66
# 역 67
# 뱏 66
# 긟 66
# 닇 68
# 쾁 65
# 쿪 65
# 뛇 68
# 쫘 65
# 겑 63
# 떺 67
# 뷟 62
# 뚋 67
# 엞 67
# 뜹 67
# 뮼 65
# 뤾 67
# 쵃 68
# 켑 38
# 햟 65
# 쵨 69
# 열 66
# 긄 67
# 옼 68
# 멦 68
# 뾀 64
# 첚 68
# 젍 66
# 첃 68
# 볲 65
# 광 67
# 배 62
# 촩 69
# 뺖 67
# 켕 67
# 쥶 66
# 툮 69
# 쵄 69
# 퀮 68
# 뾮 68
# 퇳 69
# 쾏 66
# 몌 63
# 킠 63
# 쵢 68
# 뷞 62
# 꿖 66
# 쾇 69
# 쮟 60
# 뽪 67
# 촺 69
# 쪂 63
# 뜛 64
# 쩽 65
# 캏 65
# 괥 68
# 꾈 65
# 졘 63
# 롐 66
# 겿 65
# 윮 64
# 얗 67
# 뛄 68
# 샒 65
# 빹 65
# 쯂 66
# 갬 66
# 끯 67
# 껚 67
# 쁫 67
# 쮋 66
# 빚 67
# 뮩 67
# 뱗 68
# 쭊 68
# 뙤 62
# 줺 67
# 붮 63
# 꺠 66
# 궫 67
# 켎 64
# 뾉 68
# 홴 68
# 냛 59
# 썯 66
# 쳳 64
# 쐡 59
# 냄 67
# ...

# %%
age/len(dirList)
# Out:
# 65.27461510920158
